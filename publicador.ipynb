# %% [markdown]
# # publicador

# %%
import ssl
import sys
import json
import random
import time
import paho.mqtt.client
import paho.mqtt.publish
import numpy as np
import datetime
import psycopg2
import threading
import pub

# %% [markdown]
# # conexión con la base de datos

# %%
host='echo.db.elephantsql.com'
user ='fvrwybpi'
password='Vm7b24osfoJddQLWdc6VotSmYBpOn0UT'
dbname='fvrwybpi'

# %%
connection = psycopg2.connect(host = host,
                                user= user, password =password,
                                dbname= dbname)

# %% [markdown]
# # iniciar simulación

# %%
##se crea un publicador y se conecta 
pub_estante = pub.publicador(connection, 'Automercados Plaza')
pub_estante.conectar_dispositivo()

##el publicador también será suscriptor de un canal por lo que se necesitan dos hilos para ejecutar 
##esos procesos paralelamente 
sub_t = threading.Thread(target=pub_estante.conectar_suscriptor)
pub_t = threading.Thread(target=pub_estante.iniciar_sucursal)

##iniciar hilos 
sub_t.start()
pub_t.start()
# Out:
# Cliente id: 39  Indice:  38
# Indices: [38, 47]
# se ha suscrito correctamente (b'')
# El cliente va a ir a un pasillo
# El cliente se dirige al pasillo 2
# El cliente se dirige al estante (3,)
# El cliente elige el producto: ('Pan de Trigo',)
# El cliente agarra 11 de este producto
# El cliente lo compra
# {'id_producto': 8, 'cantidad': 11, 'id_estante': 3, 'sucursal': 'sucursal1', 'hora': '2020-07-01 18:00:00.289470'}
# El cliente sigue viendo
# Cliente id: 48  Indice:  47
# Indices: [38, 47]
# El cliente va a ir a la charcutería
# {'sucursal': 'sucursal2', 'id_cliente': 48, 'id_sucursal': 2}
# El cliente se va
# entran más clientes
# Cantidad: 9
# Entran los siguientes indices de clientes: [38, 19, 15, 39, 28, 30, 41, 47, 12, 2]
# Cliente id: 16  Indice:  15
# Indices: [38, 19, 15, 39, 28, 30, 41, 47, 12, 2]
# El cliente va a ir a un pasillo
# El cliente se dirige al pasillo 4
# El cliente se dirige al estante (15,)
# El cliente elige el producto: ('Durazno',)
# El cliente agarra 11 de este producto
# El cliente lo compra
# {'id_producto': 43, 'cantidad': 11, 'id_estante': 15, 'sucursal': 'sucursal2', 'hora': '2020-07-01 18:00:00.113614'}
# El cliente sigue viendo
# Cliente id: 40  Indice:  39
# Indices: [38, 19, 15, 39, 28, 30, 41, 47, 12, 2]
# El cliente va a ir a la charcutería
# {'sucursal': 'sucursal2', 'id_cliente': 40, 'id_sucursal': 2}
# El cliente sigue viendo
# Cliente id: 29  Indice:  28
# Indices: [38, 19, 15, 39, 28, 30, 41, 47, 12, 2]
# El cliente va a ir a un pasillo
# El cliente se dirige al pasillo 3
# El cliente se dirige al estante (12,)
# El cliente elige el producto: ('Leche en Polvo',)
# El cliente agarra 96 de este producto
# El cliente lo compra
# {'id_producto': 35, 'cantidad': 96, 'id_estante': 12, 'sucursal': 'sucursal2', 'hora': '2020-07-01 18:00:00.122570'}
# El cliente va a pagar
# El total a pagar es: 384
# Cliente id: 31  Indice:  30
# Indices: [38, 19, 15, 39, 28, 30, 41, 47, 12, 2]
# El cliente va a ir a la charcutería
# {'sucursal': 'sucursal2', 'id_cliente': 31, 'id_sucursal': 2}
# El cliente se va
# Cliente id: 48  Indice:  47
# Indices: [38, 19, 15, 39, 28, 41, 47, 12, 2]
# El cliente se dirige al pasillo 3
# El cliente se dirige al estante (12,)
# El cliente elige el producto: ('Arroz',)
# El cliente agarra 171 de este producto
# El cliente lo compra
# {'id_producto': 34, 'cantidad': 171, 'id_estante': 12, 'sucursal': 'sucursal2', 'hora': '2020-07-01 18:00:00.752353'}
# El cliente sigue viendo
# Cliente id: 13  Indice:  12
# Indices: [38, 19, 15, 39, 28, 41, 47, 12, 2]
# El cliente va a ir a un pasillo
# El cliente se dirige al pasillo 1
# El cliente se dirige al estante (9,)
# El cliente elige el producto: ('Maíz',)
# El cliente agarra 20 de este producto
# El cliente lo compra
# {'id_producto': 26, 'cantidad': 20, 'id_estante': 9, 'sucursal': 'sucursal2', 'hora': '2020-07-01 18:00:00.967394'}
# El cliente sigue viendo
# Cliente id: 3  Indice:  2
# Indices: [38, 19, 15, 39, 28, 41, 47, 12, 2]
# El cliente va a ir a la charcutería
# {'sucursal': 'sucursal2', 'id_cliente': 3, 'id_sucursal': 2}
# El cliente se va
# entran más clientes
# Cantidad: 5
# Entran los siguientes indices de clientes: [38, 19, 15, 39, 28, 41, 47, 12, 5, 2, 14, 49, 33]
# Cliente id: 3  Indice:  2
# Indices: [38, 19, 15, 39, 28, 41, 47, 12, 5, 2, 14, 49, 33]
# El cliente se dirige al pasillo 2
# El cliente se dirige al estante (11,)
# El cliente elige el producto: ('Harina',)
# El cliente agarra 10 de este producto
# El cliente lo compra
# {'id_producto': 32, 'cantidad': 10, 'id_estante': 11, 'sucursal': 'sucursal2', 'hora': '2020-07-01 19:00:00.263007'}
# El cliente sigue viendo
# Cliente id: 15  Indice:  14
# Indices: [38, 19, 15, 39, 28, 41, 47, 12, 5, 2, 14, 49, 33]
# El cliente va a ir a la charcutería
# {'sucursal': 'sucursal1', 'id_cliente': 15, 'id_sucursal': 1}
# El cliente se va
# Cliente id: 34  Indice:  33
# Indices: [38, 19, 15, 39, 28, 41, 47, 12, 5, 2, 49, 33]
# El cliente va a ir a la charcutería
# {'sucursal': 'sucursal1', 'id_cliente': 34, 'id_sucursal': 1}
# El cliente sigue viendo
# entran más clientes
# Cantidad: 9
# Entran los siguientes indices de clientes: [38, 19, 15, 39, 28, 41, 47, 12, 5, 2, 49, 33, 20, 29, 3, 44, 35, 13, 7, 0, 9]
# Cliente id: 21  Indice:  20
# Indices: [38, 19, 15, 39, 28, 41, 47, 12, 5, 2, 49, 33, 20, 29, 3, 44, 35, 13, 7, 0, 9]
# El cliente va a ir a la charcutería
# {'sucursal': 'sucursal1', 'id_cliente': 21, 'id_sucursal': 1}
# El cliente se va
# Cliente id: 4  Indice:  3
# Indices: [38, 19, 15, 39, 28, 41, 47, 12, 5, 2, 49, 33, 29, 3, 44, 35, 13, 7, 0, 9]
# El cliente va a ir a la charcutería
# {'sucursal': 'sucursal1', 'id_cliente': 4, 'id_sucursal': 1}
# El cliente sigue viendo
# Cliente id: 45  Indice:  44
# Indices: [38, 19, 15, 39, 28, 41, 47, 12, 5, 2, 49, 33, 29, 3, 44, 35, 13, 7, 0, 9]
# El cliente va a ir a un pasillo
# El cliente se dirige al pasillo 4
# El cliente se dirige al estante (14,)
# El cliente elige el producto: ('Patilla',)
# El cliente agarra 52 de este producto
# El cliente lo compra
# {'id_producto': 41, 'cantidad': 52, 'id_estante': 14, 'sucursal': 'sucursal2', 'hora': '2020-07-01 18:00:00.574179'}
# El cliente sigue viendo
# Cliente id: 36  Indice:  35
# Indices: [38, 19, 15, 39, 28, 41, 47, 12, 5, 2, 49, 33, 29, 3, 44, 35, 13, 7, 0, 9]
# El cliente va a ir a la charcutería
# {'sucursal': 'sucursal1', 'id_cliente': 36, 'id_sucursal': 1}
# El cliente se va
# Cliente id: 8  Indice:  7
# Indices: [38, 19, 15, 39, 28, 41, 47, 12, 5, 2, 49, 33, 29, 3, 44, 13, 7, 0, 9]
# El cliente va a ir a la charcutería
# {'sucursal': 'sucursal2', 'id_cliente': 8, 'id_sucursal': 2}
# El cliente se va
# Cliente id: 10  Indice:  9
# Indices: [38, 19, 15, 39, 28, 41, 47, 12, 5, 2, 49, 33, 29, 3, 44, 13, 0, 9]
# El cliente va a ir a la charcutería
# {'sucursal': 'sucursal2', 'id_cliente': 10, 'id_sucursal': 2}
# El cliente se va
# entran más clientes
# Cantidad: 10
# Entran los siguientes indices de clientes: [38, 19, 15, 39, 28, 41, 47, 12, 5, 2, 49, 33, 29, 3, 44, 13, 0, 32, 23, 27, 25, 8, 17, 26, 45, 37, 31]
# Cliente id: 24  Indice:  23
# Indices: [38, 19, 15, 39, 28, 41, 47, 12, 5, 2, 49, 33, 29, 3, 44, 13, 0, 32, 23, 27, 25, 8, 17, 26, 45, 37, 31]
# El cliente va a ir a un pasillo
# El cliente se dirige al pasillo 4
# El cliente se dirige al estante (15,)
# El cliente elige el producto: ('Piña',)
# El cliente agarra 111 de este producto
# El cliente lo compra
# {'id_producto': 42, 'cantidad': 111, 'id_estante': 15, 'sucursal': 'sucursal2', 'hora': '2020-07-01 18:00:00.738835'}
# El cliente sigue viendo
# Cliente id: 28  Indice:  27
# Indices: [38, 19, 15, 39, 28, 41, 47, 12, 5, 2, 49, 33, 29, 3, 44, 13, 0, 32, 23, 27, 25, 8, 17, 26, 45, 37, 31]
# El cliente va a ir a la charcutería
# {'sucursal': 'sucursal2', 'id_cliente': 28, 'id_sucursal': 2}
# El cliente sigue viendo
# Cliente id: 26  Indice:  25
# Indices: [38, 19, 15, 39, 28, 41, 47, 12, 5, 2, 49, 33, 29, 3, 44, 13, 0, 32, 23, 27, 25, 8, 17, 26, 45, 37, 31]
# El cliente va a ir a la charcutería
# {'sucursal': 'sucursal1', 'id_cliente': 26, 'id_sucursal': 1}
# El cliente se va
# Cliente id: 18  Indice:  17
# Indices: [38, 19, 15, 39, 28, 41, 47, 12, 5, 2, 49, 33, 29, 3, 44, 13, 0, 32, 23, 27, 8, 17, 26, 45, 37, 31]
# El cliente va a ir a un pasillo
# El cliente se dirige al pasillo 5
# El cliente se dirige al estante (16,)
# El cliente elige el producto: ('Huevos',)
# El cliente agarra 68 de este producto
# El cliente lo compra
# {'id_producto': 45, 'cantidad': 68, 'id_estante': 16, 'sucursal': 'sucursal2', 'hora': '2020-07-01 18:00:00.705029'}
# El cliente va a pagar
# El total a pagar es: 1904
# Cliente id: 27  Indice:  26
# Indices: [38, 19, 15, 39, 28, 41, 47, 12, 5, 2, 49, 33, 29, 3, 44, 13, 0, 32, 23, 27, 8, 17, 26, 45, 37, 31]
# El cliente va a ir a un pasillo
# El cliente se dirige al pasillo 4
# El cliente se dirige al estante (6,)
# El cliente elige el producto: ('Lucky Charms',)
# El cliente agarra 1 de este producto
# El cliente lo compra
# {'id_producto': 16, 'cantidad': 1, 'id_estante': 6, 'sucursal': 'sucursal1', 'hora': '2020-07-01 18:00:00.101037'}
# El cliente va a pagar
# El total a pagar es: 2
# Cliente id: 46  Indice:  45
# Indices: [38, 19, 15, 39, 28, 41, 47, 12, 5, 2, 49, 33, 29, 3, 44, 13, 0, 32, 23, 27, 8, 17, 26, 45, 37, 31]
# El cliente va a ir a un pasillo
# El cliente se dirige al pasillo 3
# El cliente se dirige al estante (13,)
# El cliente elige el producto: ('Tomate',)
# El cliente agarra 10 de este producto
# El cliente lo compra
# {'id_producto': 37, 'cantidad': 10, 'id_estante': 13, 'sucursal': 'sucursal2', 'hora': '2020-07-01 18:00:00.948011'}
# El cliente sigue viendo
# Cliente id: 38  Indice:  37
# Indices: [38, 19, 15, 39, 28, 41, 47, 12, 5, 2, 49, 33, 29, 3, 44, 13, 0, 32, 23, 27, 8, 17, 26, 45, 37, 31]
# El cliente va a ir a la charcutería
# {'sucursal': 'sucursal2', 'id_cliente': 38, 'id_sucursal': 2}
# El cliente se va
# Cliente id: 39  Indice:  38
# Indices: [38, 19, 15, 39, 28, 41, 47, 12, 5, 2, 49, 33, 29, 3, 44, 13, 0, 32, 23, 27, 8, 17, 26, 45, 31]
# El cliente se dirige al pasillo 5
# El cliente se dirige al estante (8,)
# El cliente elige el producto: ('Salami',)
# El cliente agarra 4 de este producto
# El cliente lo compra
# {'id_producto': 22, 'cantidad': 4, 'id_estante': 8, 'sucursal': 'sucursal1', 'hora': '2020-07-01 18:00:00.035854'}
# El cliente va a pagar
# El total a pagar es: 325
# Cliente id: 20  Indice:  19
# Indices: [38, 19, 15, 39, 28, 41, 47, 12, 5, 2, 49, 33, 29, 3, 44, 13, 0, 32, 23, 27, 8, 17, 26, 45, 31]
# El cliente va a ir a la charcutería
# {'sucursal': 'sucursal1', 'id_cliente': 20, 'id_sucursal': 1}
# El cliente sigue viendo
# Cliente id: 16  Indice:  15
# Indices: [38, 19, 15, 39, 28, 41, 47, 12, 5, 2, 49, 33, 29, 3, 44, 13, 0, 32, 23, 27, 8, 17, 26, 45, 31]
# El cliente se dirige al pasillo 3
# El cliente se dirige al estante (12,)
# El cliente elige el producto: ('Arroz',)
# El cliente agarra 8 de este producto
# El cliente lo compra
# {'id_producto': 34, 'cantidad': 8, 'id_estante': 12, 'sucursal': 'sucursal2', 'hora': '2020-07-01 18:00:00.031355'}
# El cliente sigue viendo
# Cliente id: 40  Indice:  39
# Indices: [38, 19, 15, 39, 28, 41, 47, 12, 5, 2, 49, 33, 29, 3, 44, 13, 0, 32, 23, 27, 8, 17, 26, 45, 31]
# El cliente se dirige al pasillo 5
# El cliente se dirige al estante (16,)
# El cliente elige el producto: ('Limón',)
# El cliente agarra 30 de este producto
# El cliente lo compra
# {'id_producto': 44, 'cantidad': 30, 'id_estante': 16, 'sucursal': 'sucursal2', 'hora': '2020-07-01 18:00:00.031355'}
# El cliente va a pagar
# El total a pagar es: 390
# Cliente id: 29  Indice:  28
# Indices: [38, 19, 15, 39, 28, 41, 47, 12, 5, 2, 49, 33, 29, 3, 44, 13, 0, 32, 23, 27, 8, 17, 26, 45, 31]
# El cliente se dirige al pasillo 2
# El cliente se dirige al estante (11,)
# El cliente elige el producto: ('Harina',)
# El cliente agarra 6 de este producto
# El cliente lo compra
# {'id_producto': 32, 'cantidad': 6, 'id_estante': 11, 'sucursal': 'sucursal2', 'hora': '2020-07-01 18:00:00.031355'}
# El cliente va a pagar
# El total a pagar es: 438
# Cliente id: 42  Indice:  41
# Indices: [38, 19, 15, 39, 28, 41, 47, 12, 5, 2, 49, 33, 29, 3, 44, 13, 0, 32, 23, 27, 8, 17, 26, 45, 31]
# El cliente va a ir a un pasillo
# El cliente se dirige al pasillo 1
# El cliente se dirige al estante (1,)
# El cliente elige el producto: ('Leche',)
# El cliente agarra 8 de este producto
# El cliente lo compra
# {'id_producto': 1, 'cantidad': 8, 'id_estante': 1, 'sucursal': 'sucursal1', 'hora': '2020-07-01 18:00:00.855387'}
# El cliente sigue viendo
# Cliente id: 48  Indice:  47
# Indices: [38, 19, 15, 39, 28, 41, 47, 12, 5, 2, 49, 33, 29, 3, 44, 13, 0, 32, 23, 27, 8, 17, 26, 45, 31]
# El cliente se dirige al pasillo 5
# El cliente se dirige al estante (16,)
# El cliente elige el producto: ('Huevos',)
# El cliente agarra 31 de este producto
# El cliente lo compra
# {'id_producto': 45, 'cantidad': 31, 'id_estante': 16, 'sucursal': 'sucursal2', 'hora': '2020-07-01 18:00:00.855387'}
# El cliente sigue viendo
# Cliente id: 13  Indice:  12
# Indices: [38, 19, 15, 39, 28, 41, 47, 12, 5, 2, 49, 33, 29, 3, 44, 13, 0, 32, 23, 27, 8, 17, 26, 45, 31]
# El cliente se dirige al pasillo 1
# El cliente se dirige al estante (9,)
# El cliente elige el producto: ('Maíz',)
# El producto se acabó
# El cliente sigue viendo
# Cliente id: 6  Indice:  5
# Indices: [38, 19, 15, 39, 28, 41, 47, 12, 5, 2, 49, 33, 29, 3, 44, 13, 0, 32, 23, 27, 8, 17, 26, 45, 31]
# El cliente va a ir a un pasillo
# El cliente se dirige al pasillo 2
# El cliente se dirige al estante (3,)
# El cliente elige el producto: ('Pan de Trigo',)
# El cliente agarra 8 de este producto
# El cliente lo compra
# {'id_producto': 8, 'cantidad': 8, 'id_estante': 3, 'sucursal': 'sucursal1', 'hora': '2020-07-01 18:00:00.951917'}
# El cliente va a pagar
# El total a pagar es: 120
# Cliente id: 3  Indice:  2
# Indices: [38, 19, 15, 39, 28, 41, 47, 12, 5, 2, 49, 33, 29, 3, 44, 13, 0, 32, 23, 27, 8, 17, 26, 45, 31]
# El cliente se dirige al pasillo 3
# El cliente se dirige al estante (13,)
# El cliente elige el producto: ('Tomate',)
# El cliente agarra 87 de este producto
# El cliente lo compra
# {'id_producto': 37, 'cantidad': 87, 'id_estante': 13, 'sucursal': 'sucursal2', 'hora': '2020-07-01 18:00:00.066330'}
# El cliente sigue viendo
# Cliente id: 50  Indice:  49
# Indices: [38, 19, 15, 39, 28, 41, 47, 12, 5, 2, 49, 33, 29, 3, 44, 13, 0, 32, 23, 27, 8, 17, 26, 45, 31]
# El cliente va a ir a un pasillo
# El cliente se dirige al pasillo 1
# El cliente se dirige al estante (9,)
# El cliente elige el producto: ('Maíz',)
# El producto se acabó
# El cliente sigue viendo
# Cliente id: 34  Indice:  33
# Indices: [38, 19, 15, 39, 28, 41, 47, 12, 5, 2, 49, 33, 29, 3, 44, 13, 0, 32, 23, 27, 8, 17, 26, 45, 31]
# El cliente se dirige al pasillo 2
# El cliente se dirige al estante (3,)
# El cliente elige el producto: ('Crema de Leche',)
# El cliente agarra 5 de este producto
# El cliente lo compra
# {'id_producto': 7, 'cantidad': 5, 'id_estante': 3, 'sucursal': 'sucursal1', 'hora': '2020-07-01 18:00:00.531155'}
# El cliente va a pagar
# El total a pagar es: 95
# Cliente id: 30  Indice:  29
# Indices: [38, 19, 15, 39, 28, 41, 47, 12, 5, 2, 49, 33, 29, 3, 44, 13, 0, 32, 23, 27, 8, 17, 26, 45, 31]
# El cliente va a ir a un pasillo
# El cliente se dirige al pasillo 4
# El cliente se dirige al estante (14,)
# El cliente elige el producto: ('Fresas',)
# El cliente agarra 106 de este producto
# El cliente lo compra
# {'id_producto': 40, 'cantidad': 106, 'id_estante': 14, 'sucursal': 'sucursal2', 'hora': '2020-07-01 18:00:00.111291'}
# El cliente va a pagar
